# %%
from xgboost import XGBClassifier

import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
raw_train = pd.read_csv('train.csv', index_col='Id')
raw_test = pd.read_csv('test.csv', index_col='Id')

# %%
X_train = raw_train.copy().drop(['Cover_Type'], axis=1)
y_train = raw_train.copy()['Cover_Type']
X_test = raw_test.copy()

# %%
model = XGBClassifier()

# %%
cv_folds = 10
scores = cross_val_score(model, X_train, y_train, cv=cv_folds, scoring='accuracy')
print('Mean accuracy: {}'.format(scores.mean()))
print('Standard error: {}'.format(scores.std() / cv_folds**0.5))
# Out:
# Mean accuracy: 0.7064814814814815
# Standard error: 0.012540631312755356

# %%
importances = pd.DataFrame({'feature':X_train.columns,
                            'importance':np.round(model.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances
# Out:
#                                     importance
# feature
# Soil_Type30                              0.181
# Elevation                                0.109
# Wilderness_Area4                         0.089
# Soil_Type29                              0.050
# Soil_Type10                              0.048
# Soil_Type3                               0.044
# Soil_Type12                              0.041
# Hillshade_9am                            0.029
# Soil_Type22                              0.026
# Horizontal_Distance_To_Hydrology         0.023
# Soil_Type4                               0.023
# Wilderness_Area3                         0.022
# Soil_Type13                              0.022
# Wilderness_Area1                         0.020
# Soil_Type39                              0.020
# Soil_Type23                              0.018
# Soil_Type32                              0.017
# Soil_Type17                              0.014
# Soil_Type38                              0.014
# Soil_Type1                               0.013
# Soil_Type6                               0.013
# Horizontal_Distance_To_Fire_Points       0.013
# Hillshade_Noon                           0.013
# Horizontal_Distance_To_Roadways          0.013
# Soil_Type24                              0.011
# Soil_Type2                               0.011
# Soil_Type33                              0.010
# Soil_Type40                              0.010
# Hillshade_3pm                            0.010
# Soil_Type5                               0.010
# Wilderness_Area2                         0.009
# Aspect                                   0.008
# Vertical_Distance_To_Hydrology           0.008
# Soil_Type20                              0.008
# Soil_Type31                              0.007
# Slope                                    0.007
# Soil_Type11                              0.006
# Soil_Type35                              0.005
# Soil_Type34                              0.002
# Soil_Type9                               0.001
# Soil_Type16                              0.001
# Soil_Type15                              0.000
# Soil_Type37                              0.000
# Soil_Type36                              0.000
# Soil_Type28                              0.000
# Soil_Type7                               0.000
# Soil_Type27                              0.000
# Soil_Type26                              0.000
# Soil_Type25                              0.000
# Soil_Type8                               0.000
# Soil_Type21                              0.000
# Soil_Type19                              0.000
# Soil_Type18                              0.000
# Soil_Type14                              0.000

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
predictions = model.predict(X_test)
preds_df = pd.DataFrame({'Id': X_test.index, 'Cover_Type': predictions})
preds_df.to_csv('submission.csv', index=False)
